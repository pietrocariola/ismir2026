# %%
PATH_DATASET = "/home/gpu1/datasets/fma/fma_pool"

# %%
import librosa
import os

# %%
files = os.listdir(PATH_DATASET)

# %%
# Out:
# ['110772.mp3',
#  '096718.mp3',
#  '110166.mp3',
#  '148231.mp3',
#  '145004.mp3',
#  '115925.mp3',
#  '124873.mp3',
#  '107949.mp3',
#  '131939.mp3',
#  '106877.mp3']
