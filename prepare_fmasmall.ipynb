# %%
import os
import pandas as pd
import json
from pathlib import Path

# %%
FMA_META_PATH = "/home/gpu3/visfma/fmasmall/fma_metadata/tracks.csv" #"/.../.../fma_metadata/tracks.csv"
DS_PATH = "/home/gpu3/visfma/fmasmall/fma_small" #"/.../.../fma_small"
FILES_PER_GENRE = 100
GENRES = ['Electronic', 'Experimental', 'Folk', 'Hip-Hop', 'Instrumental', 'Pop', 'Rock']
DS_NAME = "fmasmallx"
EXCLUDE_LIST = ["011298.mp3"] #unable top open this file / replaced by one of the same genre

# %%
tracks = {
    DS_NAME: {},
}

for genre in GENRES:
    tracks[DS_NAME][genre.lower()] = []

df = pd.read_csv(FMA_META_PATH, header=1)
df = df[df["subset"]=="small"]

if Path("tracks.json").exists():
    with open("tracks.json", "r") as f:
        saved_tracks = json.load(f)

for genre in GENRES:
    g = df[df["genre_top"]==genre]
    i = 0
    j = 0
    while i < FILES_PER_GENRE:
        file = str(g.iloc[i+j, 0]).zfill(6)+".mp3"        
        while file in EXCLUDE_LIST:
            j += 1
            file = str(g.iloc[i+j, 0]).zfill(6)+".mp3"
        file_path = os.path.join(DS_PATH, file[:3], file)
        tracks[DS_NAME][genre.lower()].append(file_path)
        i += 1
        

with open("tracks.json", "w") as f:
    json.dump(tracks, f, indent=2)
# Out:
# /tmp/ipykernel_1284408/3307112504.py:8: DtypeWarning: Columns (0: Unnamed: 0) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(FMA_META_PATH, header=1)
