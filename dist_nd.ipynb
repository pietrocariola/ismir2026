# %%
import pandas as pd
import numpy as np
import transformations as tf
import os
from pathlib import Path
# Out:
# [   INFO   ] MusicExtractorSVM: no classifier models were configured by default

# %%
input_path = '/home/gpu3/visfma/embeds'
file_name = 'x_fmasmallx_ele_001482_audioclip_identity_none.npy'
transformation = 'pitchshift'
track = file_name.split('_')[2]+'_'+file_name.split('_')[3]
dataset = file_name.split('_')[1]
model = file_name.split('_')[4]

params = ['id']
for param in tf.tf_dict_params[transformation]:
    params.append(str(param)[:5])
df = pd.DataFrame(
    columns=params,
    index=params
)

for i, param1 in enumerate(params):
    if param1 == 'id':
        f1 = f"x_{dataset}_{track}_{model}_identity_none.npy"
        f1 = os.path.join(input_path, f1)
    else:
        f1 = f"x_{dataset}_{track}_{model}_{transformation}_{str(param1)[:5].replace('.', 'p')}.npy"
        f1 = os.path.join(input_path, f1)
    a1 = np.load(f1, 'r')
    for j in range(i, len(params)):
        param2 = params[j]
        if param2 == 'id':
            f2 = f"x_{dataset}_{track}_{model}_identity_none.npy"
            f2 = os.path.join(input_path, f2)
        else:
            f2 = f"x_{dataset}_{track}_{model}_{transformation}_{str(param2)[:5].replace('.', 'p')}.npy"
            f2 = os.path.join(input_path, f2)
        a2 = np.load(f2, 'r')
        d = np.sqrt(np.sum((a2-a1)**2))
        df.iloc[i,j] = d
        df.iloc[j,i] = d

df.to_csv("dist_nd.csv", index=True)
df.head(len(params))
# Out:
#            id         1         2         3         4         5         6  \
# id        0.0  0.142422  0.171673  0.190977  0.198384  0.180618  0.175332
# 1    0.142422       0.0    0.0857  0.111689  0.128894  0.114504  0.140645
# 2    0.171673    0.0857       0.0  0.081539  0.084749  0.070345  0.107171
# 3    0.190977  0.111689  0.081539       0.0  0.061233  0.083677  0.130178
# 4    0.198384  0.128894  0.084749  0.061233       0.0  0.079001  0.121877
# 5    0.180618  0.114504  0.070345  0.083677  0.079001       0.0  0.070751
# 6    0.175332  0.140645  0.107171  0.130178  0.121877  0.070751       0.0
# 7    0.205512  0.163501  0.139237  0.161149  0.156703  0.104776  0.068181
# 8    0.159887  0.149109  0.143693  0.163043  0.160378  0.122065  0.082536
# 9    0.160769  0.179525  0.163756  0.189568  0.177048  0.137224  0.091561
# 10   0.233559  0.233463  0.208925  0.227333  0.216156  0.175239  0.127855
# 11    0.19946  0.205659  0.195314  0.212594  0.205737  0.168966  0.131035
# 12   0.290919  0.224977  0.253226  0.229127  0.249773  0.252381  0.270436
# 24   0.288301  0.326776   0.32434  0.333633  0.334992  0.299091  0.272901
# -1   0.235337  0.154468   0.19572  0.172453  0.202074  0.216761  0.248879
