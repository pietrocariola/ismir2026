# %%
import pandas as pd

# %%
df = pd.read_csv("metadata.csv")
print(len(df))
df = df[ (df["transf_param_name"] != '36') &
        (df["transf_param_name"] != '48') &
        (df["transf_param_name"] != '96') &
        (df["transf_param_name"] != '-36') &
        (df["transf_param_name"] != '-48') &
        (df["transf_param_name"] != '-96') ]
print(len(df))

df.to_csv("metadata.csv", index=False)
# Out:
# 450
# 390
